# %% [markdown]
# # Week 1 Mission 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Pandas로 DataFrame 읽기

# %%
df = pd.read_csv('/Users/admin/HMG_5th/missions/w1/data/Mtcars Data.csv')

# %% [markdown]
# ### Dataframe 관련 method

# %% [markdown]
# * `head()`
#     * dataframe의 앞 인덱스를 출력해준다.
# * `tail()`
#     * dataframe의 뒷 인덱스를 출력해준다.

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.tail()
# Out:
#         Unnamed: 0   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# * `shape`
#     * 데이터의 shape을 리턴
# * `columns`
#     * 데이터의 column 명칭들을 출력해준다.
#     * 새로운 column 배열을 만들어서 대입도 가능하다.

# %%
df.shape
# Out:
# (32, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %% [markdown]
# 새로운 column 리스트를 만들어서 대입한 이후에 head()를 실행하면, 새로운 column이 잘 반영된 것을 확인할 수 있다.

# %%
new_columns = list(df.columns)
new_columns[0] = 'name'

# %%
df.columns = new_columns
df.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# * `info()`
#     * This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
#     * 이 메소드는 index dtype과, column 명, null이 아닌 필드 값의 개수, data type을 프린트해준다.
# * `dtypes`
#     * This returns a Series with the data type of each column. The result’s index is the original DataFrame’s columns. Columns with mixed types are stored with the object dtype. See the User Guide for more.
#     * 각 column의 data type을 리턴해주며, 여러개의 type이 섞여있다면, object dtype으로 명시된다.
# * `describe()`
#     * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html#pandas-dataframe-describe
#     * 통계적인 정보를 리턴해준다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.dtypes
# Out:
# name     object
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ### Gear, Transmission Features (am)

# %% [markdown]
# * `unique()`
#     * unique는 각 column에 어떤 unique한 값이 있는지 보여준다.

# %%
print(f"gear unique values {df['gear'].unique()}, length {len(df['gear'].unique())}")
print(f"Transmission Features {df['am'].unique()}, length {len(df['am'].unique())}")
# Out:
# gear unique values [4 3 5], length 3
# Transmission Features [1 0], length 2

# %% [markdown]
# #### pandas crostab method 사용하지 않는 방법

# %% [markdown]
# * dict를 이용해서 진행하는 방법

# %%
num_of_cars_by_gear_transmission_dict = {}

for gear in df['gear'].unique():
	for am in df['am'].unique():
		num_of_cars_by_gear_transmission_dict[(int(gear), int(am))] = len(df.loc[(df['gear'] == gear) & (df['am'] == am)])

x_labels = list(map(str, num_of_cars_by_gear_transmission_dict.keys()))
y_values = list(num_of_cars_by_gear_transmission_dict.values())
plt.bar(x_labels, y_values)
plt.xlabel('(Gear, Auto Transmission)')
plt.ylabel('# of Cars')
plt.title('# of Cars by Gear x Transmission')
plt.show()

# %% [markdown]
# * groupby를 이용하는 방법 (태현님 방식)

# %% [markdown]
# * size? groupby?

# %%
grouped_df = df.groupby(['gear', 'am']).size()
# Out:
# gear  am
# 3     0     15
# 4     0      4
#       1      8
# 5     1      5
# dtype: int64

# %%
grouped_df = df.groupby(['gear', 'am']).size()
plt.bar(list(map(str, grouped_df.index)), grouped_df.values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #### pandas crosstab 사용 방법

# %% [markdown]
# * [pandas.crosstab](https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html#pandas.crosstab)
# 	* 두개의 값에 대한 조합을 표시해준다.
# * [pandas.DataFrame.stack()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html#pandas-dataframe-stack)
# 	* stack은 serise로 모든 column 값의 조합에 대한 값을 리턴해준다.

# %%
crosstab_df = pd.crosstab(df['gear'], df['am'])
crosstab_df_stacked = crosstab_df.stack()
crosstab_df_stacked.plot(kind='bar', xlabel='(Gear, Auto Transmission)', ylabel='# of Cars', title='# of Cars by Gear x Transmission')
# Out:
# <Axes: title={'center': '# of Cars by Gear x Transmission'}, xlabel='(Gear, Auto Transmission)', ylabel='# of Cars'>

# %% [markdown]
# #### Subplot, Corr 파악하기

# %%
fig, axs = plt.subplots(4,3, figsize=(15,12))
# index 12번 plot은 삭제
fig.delaxes(axs[3,2])

fig.suptitle('Histograms of Variables')
for idx, col in enumerate(df.columns[1:]):
	plt.subplot(4,3,idx+1)
	plt.hist(df[col])
	plt.title(col)
plt.show()

# %%
plt.scatter(df['cyl'], df['hp'])

# %%
plt.scatter(df['mpg'], df['hp'])

# %%
corr_df = df.drop('name', axis=1)
corr_df.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
fig, axs = plt.subplots(len(corr_df.columns), len(corr_df.columns), figsize=(50,50))
idx = 1
for y_col in corr_df.columns:
	for x_col in corr_df.columns:
		plt.subplot(len(corr_df.columns), len(corr_df.columns), idx)
		if x_col == y_col:
			plt.hist(corr_df[x_col])
		else:
			plt.scatter(x_col, y_col, data=corr_df)
		plt.xlabel(x_col)
		plt.ylabel(y_col)
		idx += 1

# %% [markdown]
# # 팀 활동 요구사항

# %% [markdown]
# ### 이런 데이터셋을 분석해서 얻을 수 있는 경제적 가치는 무엇일까요? 어떤 비즈니스 상황에서 이런 데이터셋을 분석해서 어떤 경제적 가치를 얻을 수 있을까요?

# %% [markdown]
# 차량을 제작하여서 판매하는 회사의 경우, 직접 제작하여 측정해보지 않는 이상 확인하기 어려운 지표들이 존재할 것이다. 기본적으로, 연비나 가속 성능의 경우, 여러가지 실질적인 요인에 의해서 정해지기 때문에 처음부터 지표를 설정하기 어려울 것이다.
#
# 그러므로, 이러한 데이터들을 이용하여 직접 운용하기 전 설계 과정부터 직접 차체를 제작하지 않고도 성능을 예측하도록 한다면, 제작비용이 절약되는 경제적인 효과가 있을 것으로 예상된다.

# %% [markdown]
# ### 변수들 간의 상관 관계가 높은 조합을 임의로 2개 선택해서 해당 데이터 간의 상관 관계를 그래프로 그리고 어떤 결론을 내릴 수 있는지를 토의하세요.

# %% [markdown]
# #### vs와 qsec에 대해서 비교.
# vs는 엔진의 형태에 관한 요소이다.
# 직렬엔진의 경우 실린더가 일직선상에 배치되기 때문에 차지하는 넓어 무게중심이 높아지게 된다. 때문에 주행안정성이 떨어져 이와 관련된 qsec(1/4 mile 도달 시간)이 증가하게 된다.
# 반면, V자 엔진의 경우 실린더가 V 형상으로 배치되기 때문에 차지하는 공간이 좁아져 무게중심이 낮아지므로 qsec이 감소하게 된다.
# 상관계수에서 음의 값을 가지는 것을 보면 이를 확인 할 수 있다.

# %%
plt.scatter(df['vs'], df['qsec'])
plt.title('Vehicle Shape vs Quarter Mile Time')
plt.xlabel('Vehicle Shape 0 (V Shape), 1 (Straight Shape)')
plt.ylabel('Quarter Mile Time')
# Out:
# Text(0, 0.5, 'Quarter Mile Time')

# %% [markdown]
# #### 기어비(drat)과 차량 중량(wt)에 대한 비교
#  drat과 wt가 음의 상관관계로 큰 연관성을 가지기에 기어비가 높으면 무게가 낮을 것이라고 생각하고 조사한 결과, 기어비가 높은 경우 토크가 강해져 가벼운 차량에 추진력을 더할 때 유리하고, 기어비가 낮은 경우 마력이 강해져 무거운 차량을 움직이기에 유리하였다.
#  따라서 기어비에 의해 무게가 반비례로 결정되는 것이 아닌 차량의 중량이 무거운 경우 낮은 기어비를 택하고, 차량이 가벼운 경우 높은 기어비를 택하는 경향성이 나타났다.

# %%
plt.scatter(df['wt'], df['drat'])
plt.title('Weight vs Rear Axle Ratio')
plt.xlabel('Weight')
plt.ylabel('Rear Axle Ratio')
# Out:
# Text(0, 0.5, 'Rear Axle Ratio')
