# %%
import pandas as pd

# %%
# !./submit-job.sh
# Out:
# 25/01/29 11:30:22 INFO SparkContext: Running Spark version 3.5.4
# 25/01/29 11:30:22 INFO SparkContext: OS info Linux, 5.15.167.4-microsoft-standard-WSL2, amd64
# 25/01/29 11:30:22 INFO SparkContext: Java version 11.0.25
# 25/01/29 11:30:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/01/29 11:30:23 INFO ResourceUtils: ==============================================================
# 25/01/29 11:30:23 INFO ResourceUtils: No custom resources configured for spark.driver.
# 25/01/29 11:30:23 INFO ResourceUtils: ==============================================================
# 25/01/29 11:30:23 INFO SparkContext: Submitted application: PythonPi
# ...

# %%
df = pd.read_parquet("~/docker/volumes/spark/data/pi_result")

display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_parquet("${HOME}/docker/volumes/spark/data/pi_result")
#       3 display(df)
#
# File ~/workspace/softeer/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...
